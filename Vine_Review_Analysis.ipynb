# %%
import pandas as pd
import numpy as np

# %%
data = ('Vine.csv')
df = pd.read_csv(data)
df.head()
# Out:
#         review_id  star_rating  helpful_votes  total_votes vine  \
# 0   RTIS3L2M1F5SM            5              0            0    N
# 1   R1ZV7R40OLHKD            5              0            0    N
# 2  R3BH071QLH8QMC            1              0            1    N
# 3  R127K9NTSXA2YH            3              0            0    N
# 4  R32ZWUXDJPW27Q            4              0            0    N
#
#   verified_purchase
# 0                 Y
# 1                 Y
# 2                 Y
# 3                 Y
# 4                 Y

# %%
# create a new DataFrame to retrieve all the rows where the total_votes count is equal to or greater than 20 
total_votes_df = df.loc[df["total_votes"] >= 20]
total_votes_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 55        R4PKAZRQJJX14            1             21           34    N
# 74       R2CI0Y288CC7E2            1             21           35    N
# 209      R127WEQY2FM1T3            1            147          175    N
# 289      R3EZ0EPYLDA34S            1             14           31    N
# 483      R2FJ94555FZH32            2             55           60    N
# ...                 ...          ...            ...          ...  ...
# 1785688  R3GYUWLD9FWCPS            5             30           30    N
# 1785714  R26KS4Q9G04FIV            2              8           21    N
# 1785788   RU0J1ZMBCLD27            5             27           29    N
# 1785806  R1D69XH2THYKTG            5             18           20    N
# 1785935  R3U5C85OV6BUKM            4             38           43    N
#
#         verified_purchase
# 55                      N
# 74                      Y
# 209                     Y
# ...

# %%
# Retrieve all the rows where the number of helpful_votes divided by total_votes is equal to or greater than 50%.
helpful_votes_df = total_votes_df[(total_votes_df['helpful_votes']/total_votes_df['total_votes']) >= 0.5]
helpful_votes_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 55        R4PKAZRQJJX14            1             21           34    N
# 74       R2CI0Y288CC7E2            1             21           35    N
# 209      R127WEQY2FM1T3            1            147          175    N
# 483      R2FJ94555FZH32            2             55           60    N
# 537      R1U3AR67RE273L            1             51           65    N
# ...                 ...          ...            ...          ...  ...
# 1785641   RCMDCDJR16IKW            4             27           30    N
# 1785688  R3GYUWLD9FWCPS            5             30           30    N
# 1785788   RU0J1ZMBCLD27            5             27           29    N
# 1785806  R1D69XH2THYKTG            5             18           20    N
# 1785935  R3U5C85OV6BUKM            4             38           43    N
#
#         verified_purchase
# 55                      N
# 74                      Y
# 209                     Y
# ...

# %%
# retrieves all the rows where a review was written as part of the Vine program (paid)
paid_df = helpful_votes_df.loc[helpful_votes_df["vine"] == 'Y']
paid_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 32611    R3KKUSGFZWSUIY            5             56           63    Y
# 33112    R10FO5UKKVZBK2            3             23           23    Y
# 69680     RM4KSGEOR7MU1            5             19           24    Y
# 155361    RG7VRMYLEXD23            4             22           26    Y
# 239327   R11O4YSCPSNL6L            3             20           26    Y
# ...                 ...          ...            ...          ...  ...
# 1456862   RLPTVGLU0JQIP            3             42           45    Y
# 1463333  R3ASJ9SENYYYI0            5             40           46    Y
# 1481162   RNU8PK609WT6P            4            347          362    Y
# 1506354   R8YT75NJW0CM9            4             37           40    Y
# 1506642  R2EDL85YVF0PRA            5             23           32    Y
#
#         verified_purchase
# 32611                   N
# 33112                   N
# 69680                   N
# ...

# %%
#  retrieve all the rows where the review was not part of the Vine program (unpaid)
unpaid_df = helpful_votes_df.loc[helpful_votes_df["vine"] == 'N']
unpaid_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 55        R4PKAZRQJJX14            1             21           34    N
# 74       R2CI0Y288CC7E2            1             21           35    N
# 209      R127WEQY2FM1T3            1            147          175    N
# 483      R2FJ94555FZH32            2             55           60    N
# 537      R1U3AR67RE273L            1             51           65    N
# ...                 ...          ...            ...          ...  ...
# 1785641   RCMDCDJR16IKW            4             27           30    N
# 1785688  R3GYUWLD9FWCPS            5             30           30    N
# 1785788   RU0J1ZMBCLD27            5             27           29    N
# 1785806  R1D69XH2THYKTG            5             18           20    N
# 1785935  R3U5C85OV6BUKM            4             38           43    N
#
#         verified_purchase
# 55                      N
# 74                      Y
# 209                     Y
# ...

# %%
# the total number of reviews for paid
total_paid_df = paid_df.['review_id'].count()
total_paid_df
# Out:
# 94

# %%
# the total number of reviews for unpaid
total_unpaid_df = unpaid_df['review_id'].count()
total_unpaid_df
# Out:
# 39915

# %%
# the number of paid 5-star reviews 
paid_5_star = len(paid_df[(paid_df['star_rating'] == 5)])
paid_5_star
# Out:
# 48

# %%
# the number of unpaid 5-star reviews
unpaid_5_star = len(unpaid_df[(unpaid_df['star_rating'] == 5)])
unpaid_5_star
# Out:
# 15556

# %%
#  the percentage of paid 5-star reviews
percent_paid = paid_5_star / total_paid_df * 100
percent_paid
# Out:
# 51.06382978723404

# %%
#  the percentage of unpaid 5-star reviews
percent_unpaid = unpaid_5_star / total_unpaid_df * 100
percent_unpaid
# Out:
# 38.97281723662783
